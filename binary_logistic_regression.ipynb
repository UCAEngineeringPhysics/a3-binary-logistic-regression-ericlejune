# %% [markdown]
# # Binary Logistic Regression / Classification
#
# ## Background
# Binary classification is one of the most fundamental and common tasks in machine learning and deep learning.
# At its core, it's a supervised learning problem where the goal is to categorize input data into one of two possible classes or categories.
# Think of it as teaching a machine to make a "yes" or "no" decision.
# Examples of binary classification's applications are:
#
# - Spam Detection: Classifying an email as either 'spam' or 'not spam'.
# - Medical Diagnosis: Determining if a patient has a certain disease.
# - Credit Scoring: Deciding whether a loan applicant is a 'good credit risk' or a 'bad credit risk'.
#
# A sigmoid activated multi-input, single-output linear model is a decent candidate for this job.
# In this practice, you'll train such a model to categorize samples from a toy dataset into two classes.
#
# ## Objectives
# - Train a simple neural network model.
#     - Apply sigmoid activation on a linear model.
#     - Implement binary cross entropy evaluation.
#     - Practice vectorized computing.
# - Assess model's performance using a variety of metrics.
#
#
# ## Exercises:
#
# 1. <font color=#582C83>(5%) Data Pre-Processing</font>
# 2. <font color=#582C83>(10%) Model Creation</font>
# 3. <font color=#582C83>(20%) Model Assessment</font>
# 4. <font color=#582C83>(10%) Gradient of BCE Loss</font>
# 5. <font color=#582C83>(30%) Gradient Descent Model Optimization</font>
# 6. <font color=#582C83>(25%) Classification Metrics</font>

# %% [markdown]
# ## 1. Load and Pre-Process Training Dataset
#
# The dataset,
# $$\mathcal{D} = \{\mathbf{X}, \mathbf{y}\} = \begin{bmatrix} ^{(1)} \mathbf{x} & ^{(1)} y \\ ^{(2)} \mathbf{x} & ^{(2)} y \\ \vdots \\ ^{(M)} \mathbf{x} & ^{(M)} y \end{bmatrix}$$
# consists $M$ samples.
#
# Each sample has $N$ features: $^{(i)} \mathbf{x} = [^{(i)} x_1, ^{(i)} x_2, \dots, ^{(i)} x_N]$ and is labeled as $^{(i)} y \in \{0, 1\}$, where $i \in \{1, 2, ..., M\}$.
#
# In this practice, we make a toy dataset using [scikit-learn](https://scikit-learn.org/stable/index.html)'s [datasets](https://scikit-learn.org/stable/api/sklearn.datasets.html) module.
# The dataset has $M=2048$ samples, and $N=2$ features.

# %%
from sklearn.datasets import make_blobs
import numpy as np
import matplotlib.pyplot as plt

features_raw, labels_raw = make_blobs(n_samples=2048, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0, random_state=3321)
# Visualize the raw data
plt.scatter(
    features_raw[:, 0], # feature 1 values (x coords)
    features_raw[:, 1], # feature 2 values (y coords)
    s=5*np.ones(labels_raw.size), # marker size all set to 1
    c=labels_raw, # colorized labels: 0:blue, 1:red
    cmap='coolwarm'  # color map
)

# %% [markdown]
# ### <font color=#582C83>(5%) Exercise 1: Data Pre-Processing</font>
# 1. In machine learning, it is prefered to scale features into the same range: $[0, 1]$.
# 2. To avoid dimension mismatch, reshape features and labels array into two dimensions is recommended.

# %%
### START CODING HERE ### (≈ 2 lines of code)
features_train = features_raw / features_raw.max(axis=0)  # Scale features to [0, 1]
labels_train = labels_raw.reshape(-1, 1) # Reshape labels to be a column vector
### END CODING HERE ### 

# Sanity check
print(f"Samples of pre-processed features:\n {features_train[-4:]}")
print(f"Samples of pre-processed labels:\n {labels_train[-4:]}")  # Print last 4 samples of features and labels
print(f"Shape of pre-processed features:\n {features_train.shape}.")
print(f"Shape of pre-processed labels:\n {labels_train.shape}")  # Print shapes of features and labels   

# Visualize
plt.scatter(
    features_train[:, 0], 
    features_train[:, 1], 
    s=5*np.ones(labels_train.size), 
    c=labels_train, 
    cmap='coolwarm'  # color map
)
# Out:
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)

# %% [markdown]
# **Expected Outcomes**:
# ```console
# Samples of pre-processed features:
#  [[0.60810041 0.36828791]
#  [0.85139165 0.63786153]
#  [0.57346525 0.38949334]
#  [0.77146837 0.71406137]]
# Samples of pre-processed labels:
#  [[0]
#  [1]
#  [0]
#  [1]]
# Shape of pre-processed features:
#  (2048, 2).
# Shape of pre-processed labels:
#  (2048, 1)
# ```

# %% [markdown]
# ## 2. Create a Non-linear Multi-Input Single-Output Model
# Let's create a nonlinear model by applying a sigmoid function to the output of a linear model.
#
# $$\mathbf{\hat{y}} = \sigma (\mathbf{X} \cdot \mathbf{w}^T + \mathbf{b}) = \sigma(\mathbf{Z})$$
#
# The sigmoid function can be represented as,
#
# $$\sigma(\mathbf{Z}) = \frac{1}{1 + e^{-\mathbf{Z}}}$$
#
# The linear part of the model is governed by a parameter vector
# $$\mathbf{w} = [w_1, w_2, ..., w_N]_{(1, N)}$$
#
# and a bias vector
# $$\mathbf{b} = \begin{bmatrix} b \\ b \\ \vdots \\ b \end{bmatrix}_{(M, 1)}$$
#
# And, in this practice $M=2048$ and $N=2$
#
# ### <font color=#582C83>(10%) Exercise 2: Model Creation</font>
# Let's translate math to code.

# %%
def forward(in_features, weights, bias):
    """
    Compute the linear combination of inputs and weights plus bias.
    
    Args:
        in_features (np.ndarray): Input features of shape (M, N).
        weights (np.ndarray): Weights of shape (1, N).
        bias (float): Bias term.  
    Returns:
        predictions: Linear combination result of shape (M, 1).
    """
    ### START CODING HERE ### (≈ 2 lines of code)
    def sigmoid(z):
        return 1 / (1 + np.exp(-z))
    predictions = sigmoid(np.dot(in_features, weights.T) + bias)
    return predictions
    ### END CODING HERE ###

# Sanity check
w_dummy = np.array([[1.2, -2.3]])
b_dummy = 1.0
print(f"Samples of dummy prediction:\n {forward(features_train, w_dummy, b_dummy)[-4:]}")  # Print last 4 samples of dummy prediction

# Visualize dummy model decision boundary
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
# Create a meshgrid of points over the feature space
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w_dummy[0, 0] * xx + w_dummy[0, 1] * yy + b_dummy - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
# Out:
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]

# %% [markdown]
# **Expected Outcomes**:
# >
# ```console
# Samples of dummy prediction:
#  [[0.70737278]
#  [0.63519949]
#  [0.68833004]
#  [0.5703847 ]]
# ```

# %% [markdown]
# ## 3. Evaluate Model
# As same as the linear regression, we need to evaluate model performance.
# It is OK to use a Mean Squared Error (MSE) function to compute the model loss.
# It is **recommended** to use a Binary Cross Entropy (BCE) function to assess the model for a binary classification problem.
# Binary Cross Entropy (BCE) is a differentiable metric.
# $$\mathcal{L}(\mathbf{\hat{y}}, \mathbf{y}) = \frac{1}{M} \Sigma [-\mathbf{y} \log \hat{\mathbf{y}} - (1 - \mathbf{y}) \log(1 - \hat{\mathbf{y}})]$$
#
# There are other useful metrics, such as accuracy. But they are not differentiable.
# Let $TP$ be number of true positive predictions, $TN$ be number of true negative predictions, $FP$ be number of false positive predictions, $FN$ be number of false negative predictions.
# The accuracy can be calculated by:
# $$Accuracy = \frac{TP + TN}{TP+FP+TN+FN}$$
#
# ### <font color=#582C83>(20%) Exercise 3: Model Assessment</font>
# 1. Evaluate model loss with BCE.
# 2. Assess model predictions accuracy.

# %%
def bce_loss(predictions, labels):
    """
    Compute the Binary Cross Entropy (BCE) loss.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        loss: BCE loss value (float).
    """
    ### START CODING HERE ### (≈ 1 line)
    loss = -np.mean(labels * np.log(np.clip(predictions, 1e-15, 1 - 1e-15)) + (1 - labels) * np.log(1 - np.clip(predictions, 1e-15, 1 - 1e-15)))
    return loss
    ### END CODING HERE ###

def accuracy(predictions, labels):
    """
    Compute the accuracy of predictions.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
    Returns:
        acc: Accuracy value (float).
    """
    ### START CODING HERE ### (≈ 2 lines)
    predicted_classes = (predictions >= 0.5).astype(int)  # Convert probabilities to binary classes
    acc = np.mean(predicted_classes == labels)
    return acc
    ### END CODING HERE ###

# Sanity check
preds_dummy = forward(features_train, w_dummy, b_dummy)
print(f"Dummy model BCE loss: {bce_loss(preds_dummy, labels_train)}")
print(f"Dummy model accuracy: {accuracy(preds_dummy, labels_train) * 100}%")
# Out:
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model BCE loss: 0.8189666983092332
# Dummy model accuracy: 42.67578125%
# ```

# %% [markdown]
# ## 4. Compute Gradient of Loss
# Compute gradient of the BCE loss:
#
# $$\frac{\partial \mathcal{L}}{\partial \mathbf{w}} = \begin{bmatrix} \frac{\partial \mathcal{L}}{\partial w_1} & \frac{\partial \mathcal{L}}{\partial w_2} & \dots & \frac{\partial \mathcal{L}}{\partial w_N} \end{bmatrix} = \frac{1}{M} (\hat{\mathbf{y}} - \mathbf{y})^T \cdot \mathbf{X}$$
# $$\frac{\partial \mathcal{L}}{\partial b}  = \overline{\hat{\mathbf{y}} - \mathbf{y}} $$
#
# ### <font color=#582C83>(10%) Exercise 4: Gradient of BCE Loss</font>

# %%
def gradient(predictions, labels, in_features):
    """
    Compute the gradient of the BCE loss with respect to weights and bias.
    
    Args:
        predictions (np.ndarray): Predicted probabilities of shape (M, 1).
        labels (np.ndarray): True binary labels of shape (M, 1).
        in_features (np.ndarray): Input features of shape (M, N).
    Returns:
        dw: Gradient with respect to weights of shape (1, N).
        db: Gradient with respect to bias (float).
    """
    ### START CODING HERE ### (≈ 3 lines of code)
    M = labels.shape[0]  # Number of samples
    dw = ((1/M)*in_features.T @ (predictions-labels)).T  # Gradient w.r.t. weights
    db = (1/M)* np.sum(predictions-labels)  # Gradient w.r.t. bias
    return dw, db
    ### END CODING HERE ###

# Sanity check
dw_dummy, db_dummy = gradient(preds_dummy, labels_train, features_train)
print(f"Dummy model gradient w.r.t. weights: {dw_dummy}, shape: {dw_dummy.shape}")
print(f"Dummy model gradient w.r.t. bias: {db_dummy}")
# Out:
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689

# %% [markdown]
# **Expected Output**:
# >
# ```console
# Dummy model gradient w.r.t. weights: [[ 0.01011904 -0.01882587]], shape: (1, 2)
# Dummy model gradient w.r.t. bias: 0.10192657501589689
# ```

# %% [markdown]
# ## 5. Update Model Parameters
#
#
# By tweaking the model parameters along the gradient a small step (learning rate, $\alpha$) iteratively, we expect to bring the BCE loss down to a reasonable scale.
#
# - $\text{Initialize } \mathbf{w} \text{ and } b$
# - $\text{Repeat until converge}$
#     - $\mathbf{w} = \mathbf{w} - \alpha \frac{\partial \mathcal{L}}{\partial \mathbf{w}}$
#     - $b = b - \alpha \frac{\partial \mathcal{L}}{\partial b}$
#
#
#
# ### <font color=#582C83>(30%) Exercise 5: Gradient Descent Model Optimization</font>
# 1. Initialize weights and bias
# 2. Set learning rate and number of iterations
# 3. Repeat following steps:
#
#     1. Make predictions
#     2. Assess model
#     3. Compute gradient of loss
#     4. Update weights and bias
#
# <font color=red>**Note: bring training accuracy over 95% within 10000 iterations**</font>

# %%
# START CODING HERE ### (≈ 10 lines of code)
# Initialize parameters
w = np.zeros((1,features_train.shape[1]))  # Initialize weights
b = 0.0  # Initialize bias

# Set hyperparameters
learning_rate = 0.01
num_iters = 1000

# Reserve loss and accuracy storage
losses_train = []
accuracies_train = []

# Training loop
for i in range(num_iters):
    z = (features_train @ w.T +b)
    preds_train = 1 / (1 + np.exp(-z))  # Make predictions
    loss_train = -np.mean(labels_train * np.log(preds_train + 1e-12) + (1-labels_train) * np.log(1-preds_train + 1e-12)) # Assess model loss
    acc_train = np.mean((preds_train >= 0.5) == labels_train)  # Assess model accuracy
    print(f"Iteration {i+1}/{num_iters}, Loss: {loss_train:.4f}, Accuracy: {acc_train*100:.2f}%")
    losses_train.append(loss_train)
    accuracies_train.append(acc_train)
    dw, db = gradient(preds_train, labels_train, features_train)  # Compute gradient of loss
    w = w - learning_rate * dw  # Update weights
    b = b - learning_rate * db  # Update bias

### END CODING HERE ###

# Plot training loss and accuracy
plt.figure(figsize=(12, 5))
plt.subplot(1, 2, 1)
plt.plot(losses_train, label='Training Loss')
plt.xlabel('Iteration')
plt.ylabel('BCE Loss')
plt.title('Training Loss over Iterations')
plt.legend()
plt.subplot(1, 2, 2)
plt.plot(np.array(accuracies_train) * 100, label='Training Accuracy', color='orange')
plt.xlabel('Iteration')
plt.ylabel('Accuracy (%)')
plt.title('Training Accuracy over Iterations')
plt.legend()
# Out:
# Iteration 1/1000, Loss: 0.6931, Accuracy: 50.00%
# Iteration 2/1000, Loss: 0.6931, Accuracy: 50.00%
# Iteration 3/1000, Loss: 0.6930, Accuracy: 50.00%
# Iteration 4/1000, Loss: 0.6929, Accuracy: 50.00%
# Iteration 5/1000, Loss: 0.6929, Accuracy: 50.00%
# Iteration 6/1000, Loss: 0.6928, Accuracy: 50.00%
# Iteration 7/1000, Loss: 0.6927, Accuracy: 50.00%
# Iteration 8/1000, Loss: 0.6927, Accuracy: 50.00%
# Iteration 9/1000, Loss: 0.6926, Accuracy: 50.00%
# Iteration 10/1000, Loss: 0.6925, Accuracy: 50.00%
# Iteration 11/1000, Loss: 0.6925, Accuracy: 50.00%
# Iteration 12/1000, Loss: 0.6924, Accuracy: 50.00%
# Iteration 13/1000, Loss: 0.6923, Accuracy: 50.00%
# Iteration 14/1000, Loss: 0.6923, Accuracy: 50.00%
# Iteration 15/1000, Loss: 0.6922, Accuracy: 50.00%
# Iteration 16/1000, Loss: 0.6921, Accuracy: 50.00%
# Iteration 17/1000, Loss: 0.6921, Accuracy: 50.00%
# Iteration 18/1000, Loss: 0.6920, Accuracy: 50.00%
# Iteration 19/1000, Loss: 0.6919, Accuracy: 50.00%
# Iteration 20/1000, Loss: 0.6919, Accuracy: 50.00%
# Iteration 21/1000, Loss: 0.6918, Accuracy: 50.00%
# Iteration 22/1000, Loss: 0.6917, Accuracy: 50.00%
# Iteration 23/1000, Loss: 0.6917, Accuracy: 50.00%
# Iteration 24/1000, Loss: 0.6916, Accuracy: 50.00%
# Iteration 25/1000, Loss: 0.6915, Accuracy: 50.00%
# Iteration 26/1000, Loss: 0.6915, Accuracy: 50.00%
# Iteration 27/1000, Loss: 0.6914, Accuracy: 50.00%
# Iteration 28/1000, Loss: 0.6914, Accuracy: 50.00%
# Iteration 29/1000, Loss: 0.6913, Accuracy: 50.00%
# Iteration 30/1000, Loss: 0.6912, Accuracy: 50.00%
# Iteration 31/1000, Loss: 0.6912, Accuracy: 50.00%
# Iteration 32/1000, Loss: 0.6911, Accuracy: 50.00%
# Iteration 33/1000, Loss: 0.6910, Accuracy: 50.00%
# Iteration 34/1000, Loss: 0.6910, Accuracy: 50.00%
# Iteration 35/1000, Loss: 0.6909, Accuracy: 50.00%
# Iteration 36/1000, Loss: 0.6909, Accuracy: 50.00%
# Iteration 37/1000, Loss: 0.6908, Accuracy: 50.00%
# Iteration 38/1000, Loss: 0.6907, Accuracy: 50.00%
# Iteration 39/1000, Loss: 0.6907, Accuracy: 50.00%
# Iteration 40/1000, Loss: 0.6906, Accuracy: 50.00%
# Iteration 41/1000, Loss: 0.6905, Accuracy: 50.00%
# Iteration 42/1000, Loss: 0.6905, Accuracy: 50.00%
# Iteration 43/1000, Loss: 0.6904, Accuracy: 50.00%
# Iteration 44/1000, Loss: 0.6904, Accuracy: 50.00%
# Iteration 45/1000, Loss: 0.6903, Accuracy: 50.00%
# Iteration 46/1000, Loss: 0.6902, Accuracy: 50.00%
# Iteration 47/1000, Loss: 0.6902, Accuracy: 50.00%
# Iteration 48/1000, Loss: 0.6901, Accuracy: 50.00%
# Iteration 49/1000, Loss: 0.6901, Accuracy: 50.00%
# Iteration 50/1000, Loss: 0.6900, Accuracy: 50.00%
# Iteration 51/1000, Loss: 0.6899, Accuracy: 50.00%
# Iteration 52/1000, Loss: 0.6899, Accuracy: 50.00%
# Iteration 53/1000, Loss: 0.6898, Accuracy: 50.00%
# Iteration 54/1000, Loss: 0.6898, Accuracy: 50.00%
# Iteration 55/1000, Loss: 0.6897, Accuracy: 50.00%
# Iteration 56/1000, Loss: 0.6896, Accuracy: 50.00%
# Iteration 57/1000, Loss: 0.6896, Accuracy: 50.00%
# Iteration 58/1000, Loss: 0.6895, Accuracy: 50.00%
# Iteration 59/1000, Loss: 0.6895, Accuracy: 50.00%
# Iteration 60/1000, Loss: 0.6894, Accuracy: 50.00%
# Iteration 61/1000, Loss: 0.6894, Accuracy: 50.00%
# Iteration 62/1000, Loss: 0.6893, Accuracy: 50.00%
# Iteration 63/1000, Loss: 0.6892, Accuracy: 50.00%
# Iteration 64/1000, Loss: 0.6892, Accuracy: 50.00%
# Iteration 65/1000, Loss: 0.6891, Accuracy: 50.00%
# Iteration 66/1000, Loss: 0.6891, Accuracy: 50.00%
# Iteration 67/1000, Loss: 0.6890, Accuracy: 50.00%
# Iteration 68/1000, Loss: 0.6890, Accuracy: 50.00%
# Iteration 69/1000, Loss: 0.6889, Accuracy: 50.00%
# Iteration 70/1000, Loss: 0.6888, Accuracy: 50.00%
# Iteration 71/1000, Loss: 0.6888, Accuracy: 50.00%
# Iteration 72/1000, Loss: 0.6887, Accuracy: 50.00%
# Iteration 73/1000, Loss: 0.6887, Accuracy: 50.00%
# Iteration 74/1000, Loss: 0.6886, Accuracy: 50.00%
# Iteration 75/1000, Loss: 0.6886, Accuracy: 50.00%
# Iteration 76/1000, Loss: 0.6885, Accuracy: 50.00%
# Iteration 77/1000, Loss: 0.6884, Accuracy: 50.00%
# Iteration 78/1000, Loss: 0.6884, Accuracy: 50.00%
# Iteration 79/1000, Loss: 0.6883, Accuracy: 50.00%
# Iteration 80/1000, Loss: 0.6883, Accuracy: 50.00%
# Iteration 81/1000, Loss: 0.6882, Accuracy: 50.00%
# Iteration 82/1000, Loss: 0.6882, Accuracy: 50.00%
# Iteration 83/1000, Loss: 0.6881, Accuracy: 50.00%
# Iteration 84/1000, Loss: 0.6881, Accuracy: 50.00%
# Iteration 85/1000, Loss: 0.6880, Accuracy: 50.00%
# Iteration 86/1000, Loss: 0.6880, Accuracy: 50.00%
# Iteration 87/1000, Loss: 0.6879, Accuracy: 50.00%
# Iteration 88/1000, Loss: 0.6878, Accuracy: 50.00%
# Iteration 89/1000, Loss: 0.6878, Accuracy: 50.00%
# Iteration 90/1000, Loss: 0.6877, Accuracy: 50.00%
# Iteration 91/1000, Loss: 0.6877, Accuracy: 50.00%
# Iteration 92/1000, Loss: 0.6876, Accuracy: 50.00%
# Iteration 93/1000, Loss: 0.6876, Accuracy: 50.00%
# Iteration 94/1000, Loss: 0.6875, Accuracy: 50.00%
# Iteration 95/1000, Loss: 0.6875, Accuracy: 50.00%
# Iteration 96/1000, Loss: 0.6874, Accuracy: 50.00%
# Iteration 97/1000, Loss: 0.6874, Accuracy: 50.00%
# Iteration 98/1000, Loss: 0.6873, Accuracy: 50.00%
# Iteration 99/1000, Loss: 0.6873, Accuracy: 50.00%
# Iteration 100/1000, Loss: 0.6872, Accuracy: 50.00%
# Iteration 101/1000, Loss: 0.6871, Accuracy: 50.00%
# Iteration 102/1000, Loss: 0.6871, Accuracy: 50.00%
# Iteration 103/1000, Loss: 0.6870, Accuracy: 50.00%
# Iteration 104/1000, Loss: 0.6870, Accuracy: 50.00%
# Iteration 105/1000, Loss: 0.6869, Accuracy: 50.00%
# Iteration 106/1000, Loss: 0.6869, Accuracy: 50.00%
# Iteration 107/1000, Loss: 0.6868, Accuracy: 50.00%
# Iteration 108/1000, Loss: 0.6868, Accuracy: 50.00%
# Iteration 109/1000, Loss: 0.6867, Accuracy: 50.00%
# Iteration 110/1000, Loss: 0.6867, Accuracy: 50.00%
# Iteration 111/1000, Loss: 0.6866, Accuracy: 50.00%
# Iteration 112/1000, Loss: 0.6866, Accuracy: 50.00%
# Iteration 113/1000, Loss: 0.6865, Accuracy: 50.00%
# Iteration 114/1000, Loss: 0.6865, Accuracy: 50.00%
# Iteration 115/1000, Loss: 0.6864, Accuracy: 50.00%
# Iteration 116/1000, Loss: 0.6864, Accuracy: 50.00%
# Iteration 117/1000, Loss: 0.6863, Accuracy: 50.00%
# Iteration 118/1000, Loss: 0.6863, Accuracy: 50.00%
# Iteration 119/1000, Loss: 0.6862, Accuracy: 50.00%
# Iteration 120/1000, Loss: 0.6862, Accuracy: 50.00%
# Iteration 121/1000, Loss: 0.6861, Accuracy: 50.00%
# Iteration 122/1000, Loss: 0.6861, Accuracy: 50.00%
# Iteration 123/1000, Loss: 0.6860, Accuracy: 50.00%
# Iteration 124/1000, Loss: 0.6860, Accuracy: 50.00%
# Iteration 125/1000, Loss: 0.6859, Accuracy: 50.00%
# Iteration 126/1000, Loss: 0.6859, Accuracy: 50.00%
# Iteration 127/1000, Loss: 0.6858, Accuracy: 50.00%
# Iteration 128/1000, Loss: 0.6858, Accuracy: 50.00%
# Iteration 129/1000, Loss: 0.6857, Accuracy: 50.00%
# Iteration 130/1000, Loss: 0.6857, Accuracy: 50.00%
# Iteration 131/1000, Loss: 0.6856, Accuracy: 50.00%
# Iteration 132/1000, Loss: 0.6856, Accuracy: 50.00%
# Iteration 133/1000, Loss: 0.6855, Accuracy: 50.00%
# Iteration 134/1000, Loss: 0.6855, Accuracy: 50.00%
# Iteration 135/1000, Loss: 0.6854, Accuracy: 50.00%
# Iteration 136/1000, Loss: 0.6854, Accuracy: 50.00%
# Iteration 137/1000, Loss: 0.6853, Accuracy: 50.00%
# Iteration 138/1000, Loss: 0.6853, Accuracy: 50.00%
# Iteration 139/1000, Loss: 0.6852, Accuracy: 50.00%
# Iteration 140/1000, Loss: 0.6852, Accuracy: 50.00%
# Iteration 141/1000, Loss: 0.6851, Accuracy: 50.00%
# Iteration 142/1000, Loss: 0.6851, Accuracy: 50.00%
# Iteration 143/1000, Loss: 0.6850, Accuracy: 50.00%
# Iteration 144/1000, Loss: 0.6850, Accuracy: 50.00%
# Iteration 145/1000, Loss: 0.6849, Accuracy: 50.00%
# Iteration 146/1000, Loss: 0.6849, Accuracy: 50.00%
# Iteration 147/1000, Loss: 0.6848, Accuracy: 50.00%
# Iteration 148/1000, Loss: 0.6848, Accuracy: 50.00%
# Iteration 149/1000, Loss: 0.6847, Accuracy: 50.00%
# Iteration 150/1000, Loss: 0.6847, Accuracy: 50.00%
# Iteration 151/1000, Loss: 0.6846, Accuracy: 50.00%
# Iteration 152/1000, Loss: 0.6846, Accuracy: 50.00%
# Iteration 153/1000, Loss: 0.6845, Accuracy: 50.00%
# Iteration 154/1000, Loss: 0.6845, Accuracy: 50.00%
# Iteration 155/1000, Loss: 0.6844, Accuracy: 50.00%
# Iteration 156/1000, Loss: 0.6844, Accuracy: 50.00%
# Iteration 157/1000, Loss: 0.6843, Accuracy: 50.00%
# Iteration 158/1000, Loss: 0.6843, Accuracy: 50.00%
# Iteration 159/1000, Loss: 0.6842, Accuracy: 50.00%
# Iteration 160/1000, Loss: 0.6842, Accuracy: 50.00%
# Iteration 161/1000, Loss: 0.6841, Accuracy: 50.00%
# Iteration 162/1000, Loss: 0.6841, Accuracy: 50.00%
# Iteration 163/1000, Loss: 0.6840, Accuracy: 50.00%
# Iteration 164/1000, Loss: 0.6840, Accuracy: 50.00%
# Iteration 165/1000, Loss: 0.6840, Accuracy: 50.00%
# Iteration 166/1000, Loss: 0.6839, Accuracy: 50.00%
# Iteration 167/1000, Loss: 0.6839, Accuracy: 50.00%
# Iteration 168/1000, Loss: 0.6838, Accuracy: 50.00%
# Iteration 169/1000, Loss: 0.6838, Accuracy: 50.00%
# Iteration 170/1000, Loss: 0.6837, Accuracy: 50.00%
# Iteration 171/1000, Loss: 0.6837, Accuracy: 50.00%
# Iteration 172/1000, Loss: 0.6836, Accuracy: 50.00%
# Iteration 173/1000, Loss: 0.6836, Accuracy: 50.00%
# Iteration 174/1000, Loss: 0.6835, Accuracy: 50.00%
# Iteration 175/1000, Loss: 0.6835, Accuracy: 50.00%
# Iteration 176/1000, Loss: 0.6834, Accuracy: 50.00%
# Iteration 177/1000, Loss: 0.6834, Accuracy: 50.00%
# Iteration 178/1000, Loss: 0.6833, Accuracy: 50.00%
# Iteration 179/1000, Loss: 0.6833, Accuracy: 50.00%
# Iteration 180/1000, Loss: 0.6832, Accuracy: 50.00%
# Iteration 181/1000, Loss: 0.6832, Accuracy: 50.00%
# Iteration 182/1000, Loss: 0.6832, Accuracy: 50.00%
# Iteration 183/1000, Loss: 0.6831, Accuracy: 50.00%
# Iteration 184/1000, Loss: 0.6831, Accuracy: 50.00%
# Iteration 185/1000, Loss: 0.6830, Accuracy: 50.00%
# Iteration 186/1000, Loss: 0.6830, Accuracy: 50.00%
# Iteration 187/1000, Loss: 0.6829, Accuracy: 50.00%
# Iteration 188/1000, Loss: 0.6829, Accuracy: 50.00%
# Iteration 189/1000, Loss: 0.6828, Accuracy: 50.00%
# Iteration 190/1000, Loss: 0.6828, Accuracy: 50.00%
# Iteration 191/1000, Loss: 0.6827, Accuracy: 50.00%
# Iteration 192/1000, Loss: 0.6827, Accuracy: 50.00%
# Iteration 193/1000, Loss: 0.6826, Accuracy: 50.00%
# Iteration 194/1000, Loss: 0.6826, Accuracy: 50.00%
# Iteration 195/1000, Loss: 0.6826, Accuracy: 50.00%
# Iteration 196/1000, Loss: 0.6825, Accuracy: 50.00%
# Iteration 197/1000, Loss: 0.6825, Accuracy: 50.00%
# Iteration 198/1000, Loss: 0.6824, Accuracy: 50.00%
# Iteration 199/1000, Loss: 0.6824, Accuracy: 50.00%
# Iteration 200/1000, Loss: 0.6823, Accuracy: 50.00%
# Iteration 201/1000, Loss: 0.6823, Accuracy: 50.00%
# Iteration 202/1000, Loss: 0.6822, Accuracy: 50.00%
# Iteration 203/1000, Loss: 0.6822, Accuracy: 50.00%
# Iteration 204/1000, Loss: 0.6821, Accuracy: 50.00%
# Iteration 205/1000, Loss: 0.6821, Accuracy: 50.00%
# Iteration 206/1000, Loss: 0.6821, Accuracy: 50.00%
# Iteration 207/1000, Loss: 0.6820, Accuracy: 50.00%
# Iteration 208/1000, Loss: 0.6820, Accuracy: 50.00%
# Iteration 209/1000, Loss: 0.6819, Accuracy: 50.00%
# Iteration 210/1000, Loss: 0.6819, Accuracy: 50.00%
# Iteration 211/1000, Loss: 0.6818, Accuracy: 50.00%
# Iteration 212/1000, Loss: 0.6818, Accuracy: 50.00%
# Iteration 213/1000, Loss: 0.6817, Accuracy: 50.00%
# Iteration 214/1000, Loss: 0.6817, Accuracy: 50.00%
# Iteration 215/1000, Loss: 0.6816, Accuracy: 50.00%
# Iteration 216/1000, Loss: 0.6816, Accuracy: 50.00%
# Iteration 217/1000, Loss: 0.6816, Accuracy: 50.00%
# Iteration 218/1000, Loss: 0.6815, Accuracy: 50.00%
# Iteration 219/1000, Loss: 0.6815, Accuracy: 50.00%
# Iteration 220/1000, Loss: 0.6814, Accuracy: 50.00%
# Iteration 221/1000, Loss: 0.6814, Accuracy: 50.00%
# Iteration 222/1000, Loss: 0.6813, Accuracy: 50.00%
# Iteration 223/1000, Loss: 0.6813, Accuracy: 50.00%
# Iteration 224/1000, Loss: 0.6812, Accuracy: 50.00%
# Iteration 225/1000, Loss: 0.6812, Accuracy: 50.00%
# Iteration 226/1000, Loss: 0.6812, Accuracy: 50.00%
# Iteration 227/1000, Loss: 0.6811, Accuracy: 50.00%
# Iteration 228/1000, Loss: 0.6811, Accuracy: 50.00%
# Iteration 229/1000, Loss: 0.6810, Accuracy: 50.00%
# Iteration 230/1000, Loss: 0.6810, Accuracy: 50.00%
# Iteration 231/1000, Loss: 0.6809, Accuracy: 50.00%
# Iteration 232/1000, Loss: 0.6809, Accuracy: 50.00%
# Iteration 233/1000, Loss: 0.6808, Accuracy: 50.00%
# Iteration 234/1000, Loss: 0.6808, Accuracy: 50.00%
# Iteration 235/1000, Loss: 0.6808, Accuracy: 50.00%
# Iteration 236/1000, Loss: 0.6807, Accuracy: 50.00%
# Iteration 237/1000, Loss: 0.6807, Accuracy: 50.00%
# Iteration 238/1000, Loss: 0.6806, Accuracy: 50.00%
# Iteration 239/1000, Loss: 0.6806, Accuracy: 50.00%
# Iteration 240/1000, Loss: 0.6805, Accuracy: 50.00%
# Iteration 241/1000, Loss: 0.6805, Accuracy: 50.00%
# Iteration 242/1000, Loss: 0.6805, Accuracy: 50.00%
# Iteration 243/1000, Loss: 0.6804, Accuracy: 50.00%
# Iteration 244/1000, Loss: 0.6804, Accuracy: 50.00%
# Iteration 245/1000, Loss: 0.6803, Accuracy: 50.00%
# Iteration 246/1000, Loss: 0.6803, Accuracy: 50.00%
# Iteration 247/1000, Loss: 0.6802, Accuracy: 50.00%
# Iteration 248/1000, Loss: 0.6802, Accuracy: 50.00%
# Iteration 249/1000, Loss: 0.6801, Accuracy: 50.00%
# Iteration 250/1000, Loss: 0.6801, Accuracy: 50.00%
# Iteration 251/1000, Loss: 0.6801, Accuracy: 50.00%
# Iteration 252/1000, Loss: 0.6800, Accuracy: 50.00%
# Iteration 253/1000, Loss: 0.6800, Accuracy: 50.00%
# Iteration 254/1000, Loss: 0.6799, Accuracy: 50.00%
# Iteration 255/1000, Loss: 0.6799, Accuracy: 50.00%
# Iteration 256/1000, Loss: 0.6798, Accuracy: 50.00%
# Iteration 257/1000, Loss: 0.6798, Accuracy: 50.00%
# Iteration 258/1000, Loss: 0.6798, Accuracy: 50.00%
# Iteration 259/1000, Loss: 0.6797, Accuracy: 50.00%
# Iteration 260/1000, Loss: 0.6797, Accuracy: 50.00%
# Iteration 261/1000, Loss: 0.6796, Accuracy: 50.00%
# Iteration 262/1000, Loss: 0.6796, Accuracy: 50.00%
# Iteration 263/1000, Loss: 0.6795, Accuracy: 50.00%
# Iteration 264/1000, Loss: 0.6795, Accuracy: 50.00%
# Iteration 265/1000, Loss: 0.6795, Accuracy: 50.00%
# Iteration 266/1000, Loss: 0.6794, Accuracy: 50.00%
# Iteration 267/1000, Loss: 0.6794, Accuracy: 50.00%
# Iteration 268/1000, Loss: 0.6793, Accuracy: 50.00%
# Iteration 269/1000, Loss: 0.6793, Accuracy: 50.00%
# Iteration 270/1000, Loss: 0.6792, Accuracy: 50.00%
# Iteration 271/1000, Loss: 0.6792, Accuracy: 50.00%
# Iteration 272/1000, Loss: 0.6792, Accuracy: 50.00%
# Iteration 273/1000, Loss: 0.6791, Accuracy: 50.00%
# Iteration 274/1000, Loss: 0.6791, Accuracy: 50.00%
# Iteration 275/1000, Loss: 0.6790, Accuracy: 50.00%
# Iteration 276/1000, Loss: 0.6790, Accuracy: 50.00%
# Iteration 277/1000, Loss: 0.6789, Accuracy: 50.00%
# Iteration 278/1000, Loss: 0.6789, Accuracy: 50.00%
# Iteration 279/1000, Loss: 0.6789, Accuracy: 50.00%
# Iteration 280/1000, Loss: 0.6788, Accuracy: 50.00%
# Iteration 281/1000, Loss: 0.6788, Accuracy: 50.00%
# Iteration 282/1000, Loss: 0.6787, Accuracy: 50.00%
# Iteration 283/1000, Loss: 0.6787, Accuracy: 50.00%
# Iteration 284/1000, Loss: 0.6786, Accuracy: 50.00%
# Iteration 285/1000, Loss: 0.6786, Accuracy: 50.00%
# Iteration 286/1000, Loss: 0.6786, Accuracy: 50.00%
# Iteration 287/1000, Loss: 0.6785, Accuracy: 50.00%
# Iteration 288/1000, Loss: 0.6785, Accuracy: 50.00%
# Iteration 289/1000, Loss: 0.6784, Accuracy: 50.00%
# Iteration 290/1000, Loss: 0.6784, Accuracy: 50.00%
# Iteration 291/1000, Loss: 0.6783, Accuracy: 50.00%
# Iteration 292/1000, Loss: 0.6783, Accuracy: 50.00%
# Iteration 293/1000, Loss: 0.6783, Accuracy: 50.00%
# Iteration 294/1000, Loss: 0.6782, Accuracy: 50.00%
# Iteration 295/1000, Loss: 0.6782, Accuracy: 50.00%
# Iteration 296/1000, Loss: 0.6781, Accuracy: 50.00%
# Iteration 297/1000, Loss: 0.6781, Accuracy: 50.00%
# Iteration 298/1000, Loss: 0.6780, Accuracy: 50.00%
# Iteration 299/1000, Loss: 0.6780, Accuracy: 50.00%
# Iteration 300/1000, Loss: 0.6780, Accuracy: 50.00%
# Iteration 301/1000, Loss: 0.6779, Accuracy: 50.00%
# Iteration 302/1000, Loss: 0.6779, Accuracy: 50.00%
# Iteration 303/1000, Loss: 0.6778, Accuracy: 50.00%
# Iteration 304/1000, Loss: 0.6778, Accuracy: 50.00%
# Iteration 305/1000, Loss: 0.6778, Accuracy: 50.00%
# Iteration 306/1000, Loss: 0.6777, Accuracy: 50.00%
# Iteration 307/1000, Loss: 0.6777, Accuracy: 50.00%
# Iteration 308/1000, Loss: 0.6776, Accuracy: 50.00%
# Iteration 309/1000, Loss: 0.6776, Accuracy: 50.00%
# Iteration 310/1000, Loss: 0.6775, Accuracy: 50.00%
# Iteration 311/1000, Loss: 0.6775, Accuracy: 50.00%
# Iteration 312/1000, Loss: 0.6775, Accuracy: 50.00%
# Iteration 313/1000, Loss: 0.6774, Accuracy: 50.00%
# Iteration 314/1000, Loss: 0.6774, Accuracy: 50.00%
# Iteration 315/1000, Loss: 0.6773, Accuracy: 50.00%
# Iteration 316/1000, Loss: 0.6773, Accuracy: 50.00%
# Iteration 317/1000, Loss: 0.6772, Accuracy: 50.00%
# Iteration 318/1000, Loss: 0.6772, Accuracy: 50.00%
# Iteration 319/1000, Loss: 0.6772, Accuracy: 50.00%
# Iteration 320/1000, Loss: 0.6771, Accuracy: 50.00%
# Iteration 321/1000, Loss: 0.6771, Accuracy: 50.00%
# Iteration 322/1000, Loss: 0.6770, Accuracy: 50.00%
# Iteration 323/1000, Loss: 0.6770, Accuracy: 50.00%
# Iteration 324/1000, Loss: 0.6770, Accuracy: 50.00%
# Iteration 325/1000, Loss: 0.6769, Accuracy: 50.00%
# Iteration 326/1000, Loss: 0.6769, Accuracy: 50.00%
# Iteration 327/1000, Loss: 0.6768, Accuracy: 50.00%
# Iteration 328/1000, Loss: 0.6768, Accuracy: 50.00%
# Iteration 329/1000, Loss: 0.6767, Accuracy: 50.00%
# Iteration 330/1000, Loss: 0.6767, Accuracy: 50.00%
# Iteration 331/1000, Loss: 0.6767, Accuracy: 50.00%
# Iteration 332/1000, Loss: 0.6766, Accuracy: 50.00%
# Iteration 333/1000, Loss: 0.6766, Accuracy: 50.00%
# Iteration 334/1000, Loss: 0.6765, Accuracy: 50.00%
# Iteration 335/1000, Loss: 0.6765, Accuracy: 50.00%
# Iteration 336/1000, Loss: 0.6765, Accuracy: 50.00%
# Iteration 337/1000, Loss: 0.6764, Accuracy: 50.00%
# Iteration 338/1000, Loss: 0.6764, Accuracy: 50.00%
# Iteration 339/1000, Loss: 0.6763, Accuracy: 50.00%
# Iteration 340/1000, Loss: 0.6763, Accuracy: 50.00%
# Iteration 341/1000, Loss: 0.6763, Accuracy: 50.00%
# Iteration 342/1000, Loss: 0.6762, Accuracy: 50.00%
# Iteration 343/1000, Loss: 0.6762, Accuracy: 50.00%
# Iteration 344/1000, Loss: 0.6761, Accuracy: 50.00%
# Iteration 345/1000, Loss: 0.6761, Accuracy: 50.00%
# Iteration 346/1000, Loss: 0.6760, Accuracy: 50.00%
# Iteration 347/1000, Loss: 0.6760, Accuracy: 50.00%
# Iteration 348/1000, Loss: 0.6760, Accuracy: 50.00%
# Iteration 349/1000, Loss: 0.6759, Accuracy: 50.00%
# Iteration 350/1000, Loss: 0.6759, Accuracy: 50.00%
# Iteration 351/1000, Loss: 0.6758, Accuracy: 50.00%
# Iteration 352/1000, Loss: 0.6758, Accuracy: 50.00%
# Iteration 353/1000, Loss: 0.6758, Accuracy: 50.00%
# Iteration 354/1000, Loss: 0.6757, Accuracy: 50.00%
# Iteration 355/1000, Loss: 0.6757, Accuracy: 50.00%
# Iteration 356/1000, Loss: 0.6756, Accuracy: 50.00%
# Iteration 357/1000, Loss: 0.6756, Accuracy: 50.00%
# Iteration 358/1000, Loss: 0.6756, Accuracy: 50.00%
# Iteration 359/1000, Loss: 0.6755, Accuracy: 50.00%
# Iteration 360/1000, Loss: 0.6755, Accuracy: 50.00%
# Iteration 361/1000, Loss: 0.6754, Accuracy: 50.00%
# Iteration 362/1000, Loss: 0.6754, Accuracy: 50.00%
# Iteration 363/1000, Loss: 0.6753, Accuracy: 50.00%
# Iteration 364/1000, Loss: 0.6753, Accuracy: 50.00%
# Iteration 365/1000, Loss: 0.6753, Accuracy: 50.00%
# Iteration 366/1000, Loss: 0.6752, Accuracy: 50.00%
# Iteration 367/1000, Loss: 0.6752, Accuracy: 50.00%
# Iteration 368/1000, Loss: 0.6751, Accuracy: 50.00%
# Iteration 369/1000, Loss: 0.6751, Accuracy: 50.00%
# Iteration 370/1000, Loss: 0.6751, Accuracy: 50.00%
# Iteration 371/1000, Loss: 0.6750, Accuracy: 50.00%
# Iteration 372/1000, Loss: 0.6750, Accuracy: 50.00%
# Iteration 373/1000, Loss: 0.6749, Accuracy: 50.00%
# Iteration 374/1000, Loss: 0.6749, Accuracy: 50.00%
# Iteration 375/1000, Loss: 0.6749, Accuracy: 50.00%
# Iteration 376/1000, Loss: 0.6748, Accuracy: 50.00%
# Iteration 377/1000, Loss: 0.6748, Accuracy: 50.00%
# Iteration 378/1000, Loss: 0.6747, Accuracy: 50.00%
# Iteration 379/1000, Loss: 0.6747, Accuracy: 50.00%
# Iteration 380/1000, Loss: 0.6747, Accuracy: 50.00%
# Iteration 381/1000, Loss: 0.6746, Accuracy: 50.00%
# Iteration 382/1000, Loss: 0.6746, Accuracy: 50.00%
# Iteration 383/1000, Loss: 0.6745, Accuracy: 50.00%
# Iteration 384/1000, Loss: 0.6745, Accuracy: 50.00%
# Iteration 385/1000, Loss: 0.6744, Accuracy: 50.00%
# Iteration 386/1000, Loss: 0.6744, Accuracy: 50.00%
# Iteration 387/1000, Loss: 0.6744, Accuracy: 50.00%
# Iteration 388/1000, Loss: 0.6743, Accuracy: 50.00%
# Iteration 389/1000, Loss: 0.6743, Accuracy: 50.00%
# Iteration 390/1000, Loss: 0.6742, Accuracy: 50.00%
# Iteration 391/1000, Loss: 0.6742, Accuracy: 50.00%
# Iteration 392/1000, Loss: 0.6742, Accuracy: 50.00%
# Iteration 393/1000, Loss: 0.6741, Accuracy: 50.00%
# Iteration 394/1000, Loss: 0.6741, Accuracy: 50.00%
# Iteration 395/1000, Loss: 0.6740, Accuracy: 50.00%
# Iteration 396/1000, Loss: 0.6740, Accuracy: 50.00%
# Iteration 397/1000, Loss: 0.6740, Accuracy: 50.00%
# Iteration 398/1000, Loss: 0.6739, Accuracy: 50.00%
# Iteration 399/1000, Loss: 0.6739, Accuracy: 50.00%
# Iteration 400/1000, Loss: 0.6738, Accuracy: 50.00%
# Iteration 401/1000, Loss: 0.6738, Accuracy: 50.00%
# Iteration 402/1000, Loss: 0.6738, Accuracy: 50.00%
# Iteration 403/1000, Loss: 0.6737, Accuracy: 50.00%
# Iteration 404/1000, Loss: 0.6737, Accuracy: 50.00%
# Iteration 405/1000, Loss: 0.6736, Accuracy: 50.00%
# Iteration 406/1000, Loss: 0.6736, Accuracy: 50.00%
# Iteration 407/1000, Loss: 0.6736, Accuracy: 50.00%
# Iteration 408/1000, Loss: 0.6735, Accuracy: 50.00%
# Iteration 409/1000, Loss: 0.6735, Accuracy: 50.00%
# Iteration 410/1000, Loss: 0.6734, Accuracy: 50.00%
# Iteration 411/1000, Loss: 0.6734, Accuracy: 50.00%
# Iteration 412/1000, Loss: 0.6734, Accuracy: 50.00%
# Iteration 413/1000, Loss: 0.6733, Accuracy: 50.00%
# Iteration 414/1000, Loss: 0.6733, Accuracy: 50.00%
# Iteration 415/1000, Loss: 0.6732, Accuracy: 50.00%
# Iteration 416/1000, Loss: 0.6732, Accuracy: 50.00%
# Iteration 417/1000, Loss: 0.6732, Accuracy: 50.00%
# Iteration 418/1000, Loss: 0.6731, Accuracy: 50.00%
# Iteration 419/1000, Loss: 0.6731, Accuracy: 50.00%
# Iteration 420/1000, Loss: 0.6730, Accuracy: 50.00%
# Iteration 421/1000, Loss: 0.6730, Accuracy: 50.00%
# Iteration 422/1000, Loss: 0.6730, Accuracy: 50.00%
# Iteration 423/1000, Loss: 0.6729, Accuracy: 50.00%
# Iteration 424/1000, Loss: 0.6729, Accuracy: 50.00%
# Iteration 425/1000, Loss: 0.6728, Accuracy: 50.00%
# Iteration 426/1000, Loss: 0.6728, Accuracy: 50.00%
# Iteration 427/1000, Loss: 0.6728, Accuracy: 50.00%
# Iteration 428/1000, Loss: 0.6727, Accuracy: 50.00%
# Iteration 429/1000, Loss: 0.6727, Accuracy: 50.00%
# Iteration 430/1000, Loss: 0.6726, Accuracy: 50.00%
# Iteration 431/1000, Loss: 0.6726, Accuracy: 50.00%
# Iteration 432/1000, Loss: 0.6726, Accuracy: 50.00%
# Iteration 433/1000, Loss: 0.6725, Accuracy: 50.00%
# Iteration 434/1000, Loss: 0.6725, Accuracy: 50.00%
# Iteration 435/1000, Loss: 0.6724, Accuracy: 50.00%
# Iteration 436/1000, Loss: 0.6724, Accuracy: 50.00%
# Iteration 437/1000, Loss: 0.6724, Accuracy: 50.00%
# Iteration 438/1000, Loss: 0.6723, Accuracy: 50.00%
# Iteration 439/1000, Loss: 0.6723, Accuracy: 50.00%
# Iteration 440/1000, Loss: 0.6722, Accuracy: 50.00%
# Iteration 441/1000, Loss: 0.6722, Accuracy: 50.00%
# Iteration 442/1000, Loss: 0.6722, Accuracy: 50.00%
# Iteration 443/1000, Loss: 0.6721, Accuracy: 50.00%
# Iteration 444/1000, Loss: 0.6721, Accuracy: 50.00%
# Iteration 445/1000, Loss: 0.6720, Accuracy: 50.00%
# Iteration 446/1000, Loss: 0.6720, Accuracy: 50.00%
# Iteration 447/1000, Loss: 0.6720, Accuracy: 50.00%
# Iteration 448/1000, Loss: 0.6719, Accuracy: 50.00%
# Iteration 449/1000, Loss: 0.6719, Accuracy: 50.00%
# Iteration 450/1000, Loss: 0.6718, Accuracy: 50.00%
# Iteration 451/1000, Loss: 0.6718, Accuracy: 50.00%
# Iteration 452/1000, Loss: 0.6718, Accuracy: 50.00%
# Iteration 453/1000, Loss: 0.6717, Accuracy: 50.00%
# Iteration 454/1000, Loss: 0.6717, Accuracy: 50.00%
# Iteration 455/1000, Loss: 0.6716, Accuracy: 50.00%
# Iteration 456/1000, Loss: 0.6716, Accuracy: 50.00%
# Iteration 457/1000, Loss: 0.6716, Accuracy: 50.00%
# Iteration 458/1000, Loss: 0.6715, Accuracy: 50.00%
# Iteration 459/1000, Loss: 0.6715, Accuracy: 50.00%
# Iteration 460/1000, Loss: 0.6714, Accuracy: 50.00%
# Iteration 461/1000, Loss: 0.6714, Accuracy: 50.00%
# Iteration 462/1000, Loss: 0.6714, Accuracy: 50.00%
# Iteration 463/1000, Loss: 0.6713, Accuracy: 50.00%
# Iteration 464/1000, Loss: 0.6713, Accuracy: 50.00%
# Iteration 465/1000, Loss: 0.6712, Accuracy: 50.00%
# Iteration 466/1000, Loss: 0.6712, Accuracy: 50.00%
# Iteration 467/1000, Loss: 0.6712, Accuracy: 50.00%
# Iteration 468/1000, Loss: 0.6711, Accuracy: 50.00%
# Iteration 469/1000, Loss: 0.6711, Accuracy: 50.00%
# Iteration 470/1000, Loss: 0.6710, Accuracy: 50.00%
# Iteration 471/1000, Loss: 0.6710, Accuracy: 50.00%
# Iteration 472/1000, Loss: 0.6710, Accuracy: 50.00%
# Iteration 473/1000, Loss: 0.6709, Accuracy: 50.00%
# Iteration 474/1000, Loss: 0.6709, Accuracy: 50.00%
# Iteration 475/1000, Loss: 0.6708, Accuracy: 50.00%
# Iteration 476/1000, Loss: 0.6708, Accuracy: 50.00%
# Iteration 477/1000, Loss: 0.6708, Accuracy: 50.00%
# Iteration 478/1000, Loss: 0.6707, Accuracy: 50.00%
# Iteration 479/1000, Loss: 0.6707, Accuracy: 50.00%
# Iteration 480/1000, Loss: 0.6706, Accuracy: 50.00%
# Iteration 481/1000, Loss: 0.6706, Accuracy: 50.00%
# Iteration 482/1000, Loss: 0.6706, Accuracy: 50.00%
# Iteration 483/1000, Loss: 0.6705, Accuracy: 50.00%
# Iteration 484/1000, Loss: 0.6705, Accuracy: 50.00%
# Iteration 485/1000, Loss: 0.6704, Accuracy: 50.00%
# Iteration 486/1000, Loss: 0.6704, Accuracy: 50.00%
# Iteration 487/1000, Loss: 0.6704, Accuracy: 50.00%
# Iteration 488/1000, Loss: 0.6703, Accuracy: 50.00%
# Iteration 489/1000, Loss: 0.6703, Accuracy: 50.00%
# Iteration 490/1000, Loss: 0.6702, Accuracy: 50.00%
# Iteration 491/1000, Loss: 0.6702, Accuracy: 50.00%
# Iteration 492/1000, Loss: 0.6702, Accuracy: 50.00%
# Iteration 493/1000, Loss: 0.6701, Accuracy: 50.00%
# Iteration 494/1000, Loss: 0.6701, Accuracy: 50.00%
# Iteration 495/1000, Loss: 0.6700, Accuracy: 50.00%
# Iteration 496/1000, Loss: 0.6700, Accuracy: 50.00%
# Iteration 497/1000, Loss: 0.6700, Accuracy: 50.00%
# Iteration 498/1000, Loss: 0.6699, Accuracy: 50.00%
# Iteration 499/1000, Loss: 0.6699, Accuracy: 50.05%
# Iteration 500/1000, Loss: 0.6698, Accuracy: 50.05%
# Iteration 501/1000, Loss: 0.6698, Accuracy: 50.05%
# Iteration 502/1000, Loss: 0.6698, Accuracy: 50.05%
# Iteration 503/1000, Loss: 0.6697, Accuracy: 50.05%
# Iteration 504/1000, Loss: 0.6697, Accuracy: 50.05%
# Iteration 505/1000, Loss: 0.6697, Accuracy: 50.05%
# Iteration 506/1000, Loss: 0.6696, Accuracy: 50.05%
# Iteration 507/1000, Loss: 0.6696, Accuracy: 50.05%
# Iteration 508/1000, Loss: 0.6695, Accuracy: 50.05%
# Iteration 509/1000, Loss: 0.6695, Accuracy: 50.05%
# Iteration 510/1000, Loss: 0.6695, Accuracy: 50.05%
# Iteration 511/1000, Loss: 0.6694, Accuracy: 50.05%
# Iteration 512/1000, Loss: 0.6694, Accuracy: 50.05%
# Iteration 513/1000, Loss: 0.6693, Accuracy: 50.05%
# Iteration 514/1000, Loss: 0.6693, Accuracy: 50.05%
# Iteration 515/1000, Loss: 0.6693, Accuracy: 50.05%
# Iteration 516/1000, Loss: 0.6692, Accuracy: 50.05%
# Iteration 517/1000, Loss: 0.6692, Accuracy: 50.05%
# Iteration 518/1000, Loss: 0.6691, Accuracy: 50.05%
# Iteration 519/1000, Loss: 0.6691, Accuracy: 50.05%
# Iteration 520/1000, Loss: 0.6691, Accuracy: 50.10%
# Iteration 521/1000, Loss: 0.6690, Accuracy: 50.10%
# Iteration 522/1000, Loss: 0.6690, Accuracy: 50.10%
# Iteration 523/1000, Loss: 0.6689, Accuracy: 50.10%
# Iteration 524/1000, Loss: 0.6689, Accuracy: 50.10%
# Iteration 525/1000, Loss: 0.6689, Accuracy: 50.10%
# Iteration 526/1000, Loss: 0.6688, Accuracy: 50.10%
# Iteration 527/1000, Loss: 0.6688, Accuracy: 50.10%
# Iteration 528/1000, Loss: 0.6687, Accuracy: 50.10%
# Iteration 529/1000, Loss: 0.6687, Accuracy: 50.10%
# Iteration 530/1000, Loss: 0.6687, Accuracy: 50.10%
# Iteration 531/1000, Loss: 0.6686, Accuracy: 50.10%
# Iteration 532/1000, Loss: 0.6686, Accuracy: 50.10%
# Iteration 533/1000, Loss: 0.6685, Accuracy: 50.10%
# Iteration 534/1000, Loss: 0.6685, Accuracy: 50.10%
# Iteration 535/1000, Loss: 0.6685, Accuracy: 50.10%
# Iteration 536/1000, Loss: 0.6684, Accuracy: 50.10%
# Iteration 537/1000, Loss: 0.6684, Accuracy: 50.10%
# Iteration 538/1000, Loss: 0.6684, Accuracy: 50.10%
# Iteration 539/1000, Loss: 0.6683, Accuracy: 50.10%
# Iteration 540/1000, Loss: 0.6683, Accuracy: 50.10%
# Iteration 541/1000, Loss: 0.6682, Accuracy: 50.10%
# Iteration 542/1000, Loss: 0.6682, Accuracy: 50.10%
# Iteration 543/1000, Loss: 0.6682, Accuracy: 50.10%
# Iteration 544/1000, Loss: 0.6681, Accuracy: 50.10%
# Iteration 545/1000, Loss: 0.6681, Accuracy: 50.15%
# Iteration 546/1000, Loss: 0.6680, Accuracy: 50.15%
# Iteration 547/1000, Loss: 0.6680, Accuracy: 50.15%
# Iteration 548/1000, Loss: 0.6680, Accuracy: 50.15%
# Iteration 549/1000, Loss: 0.6679, Accuracy: 50.15%
# Iteration 550/1000, Loss: 0.6679, Accuracy: 50.15%
# Iteration 551/1000, Loss: 0.6678, Accuracy: 50.15%
# Iteration 552/1000, Loss: 0.6678, Accuracy: 50.15%
# Iteration 553/1000, Loss: 0.6678, Accuracy: 50.15%
# Iteration 554/1000, Loss: 0.6677, Accuracy: 50.15%
# Iteration 555/1000, Loss: 0.6677, Accuracy: 50.15%
# Iteration 556/1000, Loss: 0.6676, Accuracy: 50.15%
# Iteration 557/1000, Loss: 0.6676, Accuracy: 50.15%
# Iteration 558/1000, Loss: 0.6676, Accuracy: 50.15%
# Iteration 559/1000, Loss: 0.6675, Accuracy: 50.15%
# Iteration 560/1000, Loss: 0.6675, Accuracy: 50.15%
# Iteration 561/1000, Loss: 0.6675, Accuracy: 50.15%
# Iteration 562/1000, Loss: 0.6674, Accuracy: 50.15%
# Iteration 563/1000, Loss: 0.6674, Accuracy: 50.15%
# Iteration 564/1000, Loss: 0.6673, Accuracy: 50.15%
# Iteration 565/1000, Loss: 0.6673, Accuracy: 50.15%
# Iteration 566/1000, Loss: 0.6673, Accuracy: 50.15%
# Iteration 567/1000, Loss: 0.6672, Accuracy: 50.20%
# Iteration 568/1000, Loss: 0.6672, Accuracy: 50.20%
# Iteration 569/1000, Loss: 0.6671, Accuracy: 50.20%
# Iteration 570/1000, Loss: 0.6671, Accuracy: 50.20%
# Iteration 571/1000, Loss: 0.6671, Accuracy: 50.20%
# Iteration 572/1000, Loss: 0.6670, Accuracy: 50.20%
# Iteration 573/1000, Loss: 0.6670, Accuracy: 50.20%
# Iteration 574/1000, Loss: 0.6669, Accuracy: 50.20%
# Iteration 575/1000, Loss: 0.6669, Accuracy: 50.20%
# Iteration 576/1000, Loss: 0.6669, Accuracy: 50.20%
# Iteration 577/1000, Loss: 0.6668, Accuracy: 50.20%
# Iteration 578/1000, Loss: 0.6668, Accuracy: 50.20%
# Iteration 579/1000, Loss: 0.6668, Accuracy: 50.20%
# Iteration 580/1000, Loss: 0.6667, Accuracy: 50.20%
# Iteration 581/1000, Loss: 0.6667, Accuracy: 50.20%
# Iteration 582/1000, Loss: 0.6666, Accuracy: 50.20%
# Iteration 583/1000, Loss: 0.6666, Accuracy: 50.20%
# Iteration 584/1000, Loss: 0.6666, Accuracy: 50.20%
# Iteration 585/1000, Loss: 0.6665, Accuracy: 50.20%
# Iteration 586/1000, Loss: 0.6665, Accuracy: 50.20%
# Iteration 587/1000, Loss: 0.6664, Accuracy: 50.20%
# Iteration 588/1000, Loss: 0.6664, Accuracy: 50.20%
# Iteration 589/1000, Loss: 0.6664, Accuracy: 50.20%
# Iteration 590/1000, Loss: 0.6663, Accuracy: 50.20%
# Iteration 591/1000, Loss: 0.6663, Accuracy: 50.20%
# Iteration 592/1000, Loss: 0.6662, Accuracy: 50.20%
# Iteration 593/1000, Loss: 0.6662, Accuracy: 50.20%
# Iteration 594/1000, Loss: 0.6662, Accuracy: 50.20%
# Iteration 595/1000, Loss: 0.6661, Accuracy: 50.20%
# Iteration 596/1000, Loss: 0.6661, Accuracy: 50.20%
# Iteration 597/1000, Loss: 0.6661, Accuracy: 50.20%
# Iteration 598/1000, Loss: 0.6660, Accuracy: 50.20%
# Iteration 599/1000, Loss: 0.6660, Accuracy: 50.20%
# Iteration 600/1000, Loss: 0.6659, Accuracy: 50.20%
# Iteration 601/1000, Loss: 0.6659, Accuracy: 50.20%
# Iteration 602/1000, Loss: 0.6659, Accuracy: 50.20%
# Iteration 603/1000, Loss: 0.6658, Accuracy: 50.20%
# Iteration 604/1000, Loss: 0.6658, Accuracy: 50.20%
# Iteration 605/1000, Loss: 0.6657, Accuracy: 50.20%
# Iteration 606/1000, Loss: 0.6657, Accuracy: 50.20%
# Iteration 607/1000, Loss: 0.6657, Accuracy: 50.20%
# Iteration 608/1000, Loss: 0.6656, Accuracy: 50.29%
# Iteration 609/1000, Loss: 0.6656, Accuracy: 50.34%
# Iteration 610/1000, Loss: 0.6655, Accuracy: 50.34%
# Iteration 611/1000, Loss: 0.6655, Accuracy: 50.34%
# Iteration 612/1000, Loss: 0.6655, Accuracy: 50.34%
# Iteration 613/1000, Loss: 0.6654, Accuracy: 50.34%
# Iteration 614/1000, Loss: 0.6654, Accuracy: 50.34%
# Iteration 615/1000, Loss: 0.6654, Accuracy: 50.34%
# Iteration 616/1000, Loss: 0.6653, Accuracy: 50.34%
# Iteration 617/1000, Loss: 0.6653, Accuracy: 50.34%
# Iteration 618/1000, Loss: 0.6652, Accuracy: 50.34%
# Iteration 619/1000, Loss: 0.6652, Accuracy: 50.34%
# Iteration 620/1000, Loss: 0.6652, Accuracy: 50.34%
# Iteration 621/1000, Loss: 0.6651, Accuracy: 50.34%
# Iteration 622/1000, Loss: 0.6651, Accuracy: 50.34%
# Iteration 623/1000, Loss: 0.6650, Accuracy: 50.34%
# Iteration 624/1000, Loss: 0.6650, Accuracy: 50.34%
# Iteration 625/1000, Loss: 0.6650, Accuracy: 50.34%
# Iteration 626/1000, Loss: 0.6649, Accuracy: 50.34%
# Iteration 627/1000, Loss: 0.6649, Accuracy: 50.34%
# Iteration 628/1000, Loss: 0.6648, Accuracy: 50.34%
# Iteration 629/1000, Loss: 0.6648, Accuracy: 50.34%
# Iteration 630/1000, Loss: 0.6648, Accuracy: 50.34%
# Iteration 631/1000, Loss: 0.6647, Accuracy: 50.34%
# Iteration 632/1000, Loss: 0.6647, Accuracy: 50.34%
# Iteration 633/1000, Loss: 0.6647, Accuracy: 50.34%
# Iteration 634/1000, Loss: 0.6646, Accuracy: 50.34%
# Iteration 635/1000, Loss: 0.6646, Accuracy: 50.34%
# Iteration 636/1000, Loss: 0.6645, Accuracy: 50.39%
# Iteration 637/1000, Loss: 0.6645, Accuracy: 50.39%
# Iteration 638/1000, Loss: 0.6645, Accuracy: 50.39%
# Iteration 639/1000, Loss: 0.6644, Accuracy: 50.39%
# Iteration 640/1000, Loss: 0.6644, Accuracy: 50.39%
# Iteration 641/1000, Loss: 0.6643, Accuracy: 50.39%
# Iteration 642/1000, Loss: 0.6643, Accuracy: 50.39%
# Iteration 643/1000, Loss: 0.6643, Accuracy: 50.39%
# Iteration 644/1000, Loss: 0.6642, Accuracy: 50.39%
# Iteration 645/1000, Loss: 0.6642, Accuracy: 50.39%
# Iteration 646/1000, Loss: 0.6642, Accuracy: 50.39%
# Iteration 647/1000, Loss: 0.6641, Accuracy: 50.44%
# Iteration 648/1000, Loss: 0.6641, Accuracy: 50.44%
# Iteration 649/1000, Loss: 0.6640, Accuracy: 50.44%
# Iteration 650/1000, Loss: 0.6640, Accuracy: 50.44%
# Iteration 651/1000, Loss: 0.6640, Accuracy: 50.44%
# Iteration 652/1000, Loss: 0.6639, Accuracy: 50.44%
# Iteration 653/1000, Loss: 0.6639, Accuracy: 50.44%
# Iteration 654/1000, Loss: 0.6638, Accuracy: 50.44%
# Iteration 655/1000, Loss: 0.6638, Accuracy: 50.44%
# Iteration 656/1000, Loss: 0.6638, Accuracy: 50.44%
# Iteration 657/1000, Loss: 0.6637, Accuracy: 50.49%
# Iteration 658/1000, Loss: 0.6637, Accuracy: 50.49%
# Iteration 659/1000, Loss: 0.6637, Accuracy: 50.54%
# Iteration 660/1000, Loss: 0.6636, Accuracy: 50.54%
# Iteration 661/1000, Loss: 0.6636, Accuracy: 50.54%
# Iteration 662/1000, Loss: 0.6635, Accuracy: 50.59%
# Iteration 663/1000, Loss: 0.6635, Accuracy: 50.63%
# Iteration 664/1000, Loss: 0.6635, Accuracy: 50.63%
# Iteration 665/1000, Loss: 0.6634, Accuracy: 50.68%
# Iteration 666/1000, Loss: 0.6634, Accuracy: 50.68%
# Iteration 667/1000, Loss: 0.6633, Accuracy: 50.68%
# Iteration 668/1000, Loss: 0.6633, Accuracy: 50.68%
# Iteration 669/1000, Loss: 0.6633, Accuracy: 50.68%
# Iteration 670/1000, Loss: 0.6632, Accuracy: 50.68%
# Iteration 671/1000, Loss: 0.6632, Accuracy: 50.68%
# Iteration 672/1000, Loss: 0.6632, Accuracy: 50.73%
# Iteration 673/1000, Loss: 0.6631, Accuracy: 50.73%
# Iteration 674/1000, Loss: 0.6631, Accuracy: 50.73%
# Iteration 675/1000, Loss: 0.6630, Accuracy: 50.73%
# Iteration 676/1000, Loss: 0.6630, Accuracy: 50.73%
# Iteration 677/1000, Loss: 0.6630, Accuracy: 50.73%
# Iteration 678/1000, Loss: 0.6629, Accuracy: 50.73%
# Iteration 679/1000, Loss: 0.6629, Accuracy: 50.73%
# Iteration 680/1000, Loss: 0.6628, Accuracy: 50.73%
# Iteration 681/1000, Loss: 0.6628, Accuracy: 50.73%
# Iteration 682/1000, Loss: 0.6628, Accuracy: 50.73%
# Iteration 683/1000, Loss: 0.6627, Accuracy: 50.78%
# Iteration 684/1000, Loss: 0.6627, Accuracy: 50.78%
# Iteration 685/1000, Loss: 0.6627, Accuracy: 50.78%
# Iteration 686/1000, Loss: 0.6626, Accuracy: 50.83%
# Iteration 687/1000, Loss: 0.6626, Accuracy: 50.83%
# Iteration 688/1000, Loss: 0.6625, Accuracy: 50.83%
# Iteration 689/1000, Loss: 0.6625, Accuracy: 50.83%
# Iteration 690/1000, Loss: 0.6625, Accuracy: 50.83%
# Iteration 691/1000, Loss: 0.6624, Accuracy: 50.83%
# Iteration 692/1000, Loss: 0.6624, Accuracy: 50.83%
# Iteration 693/1000, Loss: 0.6623, Accuracy: 50.83%
# Iteration 694/1000, Loss: 0.6623, Accuracy: 50.83%
# Iteration 695/1000, Loss: 0.6623, Accuracy: 50.83%
# Iteration 696/1000, Loss: 0.6622, Accuracy: 50.88%
# Iteration 697/1000, Loss: 0.6622, Accuracy: 50.88%
# Iteration 698/1000, Loss: 0.6622, Accuracy: 50.88%
# Iteration 699/1000, Loss: 0.6621, Accuracy: 50.88%
# Iteration 700/1000, Loss: 0.6621, Accuracy: 50.88%
# Iteration 701/1000, Loss: 0.6620, Accuracy: 50.88%
# Iteration 702/1000, Loss: 0.6620, Accuracy: 50.88%
# Iteration 703/1000, Loss: 0.6620, Accuracy: 50.88%
# Iteration 704/1000, Loss: 0.6619, Accuracy: 50.88%
# Iteration 705/1000, Loss: 0.6619, Accuracy: 50.88%
# Iteration 706/1000, Loss: 0.6618, Accuracy: 50.88%
# Iteration 707/1000, Loss: 0.6618, Accuracy: 50.88%
# Iteration 708/1000, Loss: 0.6618, Accuracy: 50.93%
# Iteration 709/1000, Loss: 0.6617, Accuracy: 50.93%
# Iteration 710/1000, Loss: 0.6617, Accuracy: 50.93%
# Iteration 711/1000, Loss: 0.6617, Accuracy: 50.93%
# Iteration 712/1000, Loss: 0.6616, Accuracy: 50.93%
# Iteration 713/1000, Loss: 0.6616, Accuracy: 50.93%
# Iteration 714/1000, Loss: 0.6615, Accuracy: 50.93%
# Iteration 715/1000, Loss: 0.6615, Accuracy: 50.93%
# Iteration 716/1000, Loss: 0.6615, Accuracy: 50.93%
# Iteration 717/1000, Loss: 0.6614, Accuracy: 50.93%
# Iteration 718/1000, Loss: 0.6614, Accuracy: 50.93%
# Iteration 719/1000, Loss: 0.6613, Accuracy: 50.93%
# Iteration 720/1000, Loss: 0.6613, Accuracy: 50.98%
# Iteration 721/1000, Loss: 0.6613, Accuracy: 50.98%
# Iteration 722/1000, Loss: 0.6612, Accuracy: 51.03%
# Iteration 723/1000, Loss: 0.6612, Accuracy: 51.03%
# Iteration 724/1000, Loss: 0.6612, Accuracy: 51.03%
# Iteration 725/1000, Loss: 0.6611, Accuracy: 51.03%
# Iteration 726/1000, Loss: 0.6611, Accuracy: 51.03%
# Iteration 727/1000, Loss: 0.6610, Accuracy: 51.03%
# Iteration 728/1000, Loss: 0.6610, Accuracy: 51.03%
# Iteration 729/1000, Loss: 0.6610, Accuracy: 51.03%
# Iteration 730/1000, Loss: 0.6609, Accuracy: 51.03%
# Iteration 731/1000, Loss: 0.6609, Accuracy: 51.03%
# Iteration 732/1000, Loss: 0.6609, Accuracy: 51.03%
# Iteration 733/1000, Loss: 0.6608, Accuracy: 51.07%
# Iteration 734/1000, Loss: 0.6608, Accuracy: 51.07%
# Iteration 735/1000, Loss: 0.6607, Accuracy: 51.07%
# Iteration 736/1000, Loss: 0.6607, Accuracy: 51.07%
# Iteration 737/1000, Loss: 0.6607, Accuracy: 51.12%
# Iteration 738/1000, Loss: 0.6606, Accuracy: 51.12%
# Iteration 739/1000, Loss: 0.6606, Accuracy: 51.12%
# Iteration 740/1000, Loss: 0.6605, Accuracy: 51.22%
# Iteration 741/1000, Loss: 0.6605, Accuracy: 51.22%
# Iteration 742/1000, Loss: 0.6605, Accuracy: 51.22%
# Iteration 743/1000, Loss: 0.6604, Accuracy: 51.22%
# Iteration 744/1000, Loss: 0.6604, Accuracy: 51.22%
# Iteration 745/1000, Loss: 0.6604, Accuracy: 51.22%
# Iteration 746/1000, Loss: 0.6603, Accuracy: 51.22%
# Iteration 747/1000, Loss: 0.6603, Accuracy: 51.27%
# Iteration 748/1000, Loss: 0.6602, Accuracy: 51.27%
# Iteration 749/1000, Loss: 0.6602, Accuracy: 51.27%
# Iteration 750/1000, Loss: 0.6602, Accuracy: 51.27%
# Iteration 751/1000, Loss: 0.6601, Accuracy: 51.27%
# Iteration 752/1000, Loss: 0.6601, Accuracy: 51.27%
# Iteration 753/1000, Loss: 0.6601, Accuracy: 51.32%
# Iteration 754/1000, Loss: 0.6600, Accuracy: 51.32%
# Iteration 755/1000, Loss: 0.6600, Accuracy: 51.32%
# Iteration 756/1000, Loss: 0.6599, Accuracy: 51.32%
# Iteration 757/1000, Loss: 0.6599, Accuracy: 51.32%
# Iteration 758/1000, Loss: 0.6599, Accuracy: 51.32%
# Iteration 759/1000, Loss: 0.6598, Accuracy: 51.32%
# Iteration 760/1000, Loss: 0.6598, Accuracy: 51.42%
# Iteration 761/1000, Loss: 0.6597, Accuracy: 51.42%
# Iteration 762/1000, Loss: 0.6597, Accuracy: 51.42%
# Iteration 763/1000, Loss: 0.6597, Accuracy: 51.46%
# Iteration 764/1000, Loss: 0.6596, Accuracy: 51.46%
# Iteration 765/1000, Loss: 0.6596, Accuracy: 51.46%
# Iteration 766/1000, Loss: 0.6596, Accuracy: 51.46%
# Iteration 767/1000, Loss: 0.6595, Accuracy: 51.46%
# Iteration 768/1000, Loss: 0.6595, Accuracy: 51.51%
# Iteration 769/1000, Loss: 0.6594, Accuracy: 51.51%
# Iteration 770/1000, Loss: 0.6594, Accuracy: 51.51%
# Iteration 771/1000, Loss: 0.6594, Accuracy: 51.56%
# Iteration 772/1000, Loss: 0.6593, Accuracy: 51.56%
# Iteration 773/1000, Loss: 0.6593, Accuracy: 51.56%
# Iteration 774/1000, Loss: 0.6593, Accuracy: 51.56%
# Iteration 775/1000, Loss: 0.6592, Accuracy: 51.56%
# Iteration 776/1000, Loss: 0.6592, Accuracy: 51.56%
# Iteration 777/1000, Loss: 0.6591, Accuracy: 51.56%
# Iteration 778/1000, Loss: 0.6591, Accuracy: 51.56%
# Iteration 779/1000, Loss: 0.6591, Accuracy: 51.61%
# Iteration 780/1000, Loss: 0.6590, Accuracy: 51.66%
# Iteration 781/1000, Loss: 0.6590, Accuracy: 51.71%
# Iteration 782/1000, Loss: 0.6590, Accuracy: 51.71%
# Iteration 783/1000, Loss: 0.6589, Accuracy: 51.71%
# Iteration 784/1000, Loss: 0.6589, Accuracy: 51.76%
# Iteration 785/1000, Loss: 0.6588, Accuracy: 51.76%
# Iteration 786/1000, Loss: 0.6588, Accuracy: 51.76%
# Iteration 787/1000, Loss: 0.6588, Accuracy: 51.76%
# Iteration 788/1000, Loss: 0.6587, Accuracy: 51.76%
# Iteration 789/1000, Loss: 0.6587, Accuracy: 51.81%
# Iteration 790/1000, Loss: 0.6586, Accuracy: 51.81%
# Iteration 791/1000, Loss: 0.6586, Accuracy: 51.86%
# Iteration 792/1000, Loss: 0.6586, Accuracy: 51.90%
# Iteration 793/1000, Loss: 0.6585, Accuracy: 51.90%
# Iteration 794/1000, Loss: 0.6585, Accuracy: 51.90%
# Iteration 795/1000, Loss: 0.6585, Accuracy: 51.90%
# Iteration 796/1000, Loss: 0.6584, Accuracy: 51.95%
# Iteration 797/1000, Loss: 0.6584, Accuracy: 51.95%
# Iteration 798/1000, Loss: 0.6583, Accuracy: 52.00%
# Iteration 799/1000, Loss: 0.6583, Accuracy: 52.05%
# Iteration 800/1000, Loss: 0.6583, Accuracy: 52.10%
# Iteration 801/1000, Loss: 0.6582, Accuracy: 52.10%
# Iteration 802/1000, Loss: 0.6582, Accuracy: 52.15%
# Iteration 803/1000, Loss: 0.6582, Accuracy: 52.15%
# Iteration 804/1000, Loss: 0.6581, Accuracy: 52.15%
# Iteration 805/1000, Loss: 0.6581, Accuracy: 52.15%
# Iteration 806/1000, Loss: 0.6580, Accuracy: 52.15%
# Iteration 807/1000, Loss: 0.6580, Accuracy: 52.15%
# Iteration 808/1000, Loss: 0.6580, Accuracy: 52.20%
# Iteration 809/1000, Loss: 0.6579, Accuracy: 52.20%
# Iteration 810/1000, Loss: 0.6579, Accuracy: 52.20%
# Iteration 811/1000, Loss: 0.6579, Accuracy: 52.20%
# Iteration 812/1000, Loss: 0.6578, Accuracy: 52.20%
# Iteration 813/1000, Loss: 0.6578, Accuracy: 52.20%
# Iteration 814/1000, Loss: 0.6577, Accuracy: 52.20%
# Iteration 815/1000, Loss: 0.6577, Accuracy: 52.29%
# Iteration 816/1000, Loss: 0.6577, Accuracy: 52.29%
# Iteration 817/1000, Loss: 0.6576, Accuracy: 52.29%
# Iteration 818/1000, Loss: 0.6576, Accuracy: 52.29%
# Iteration 819/1000, Loss: 0.6575, Accuracy: 52.29%
# Iteration 820/1000, Loss: 0.6575, Accuracy: 52.34%
# Iteration 821/1000, Loss: 0.6575, Accuracy: 52.49%
# Iteration 822/1000, Loss: 0.6574, Accuracy: 52.54%
# Iteration 823/1000, Loss: 0.6574, Accuracy: 52.54%
# Iteration 824/1000, Loss: 0.6574, Accuracy: 52.59%
# Iteration 825/1000, Loss: 0.6573, Accuracy: 52.69%
# Iteration 826/1000, Loss: 0.6573, Accuracy: 52.69%
# Iteration 827/1000, Loss: 0.6572, Accuracy: 52.73%
# Iteration 828/1000, Loss: 0.6572, Accuracy: 52.73%
# Iteration 829/1000, Loss: 0.6572, Accuracy: 52.78%
# Iteration 830/1000, Loss: 0.6571, Accuracy: 52.78%
# Iteration 831/1000, Loss: 0.6571, Accuracy: 52.83%
# Iteration 832/1000, Loss: 0.6571, Accuracy: 52.83%
# Iteration 833/1000, Loss: 0.6570, Accuracy: 52.83%
# Iteration 834/1000, Loss: 0.6570, Accuracy: 52.93%
# Iteration 835/1000, Loss: 0.6569, Accuracy: 52.93%
# Iteration 836/1000, Loss: 0.6569, Accuracy: 52.93%
# Iteration 837/1000, Loss: 0.6569, Accuracy: 52.93%
# Iteration 838/1000, Loss: 0.6568, Accuracy: 52.93%
# Iteration 839/1000, Loss: 0.6568, Accuracy: 52.93%
# Iteration 840/1000, Loss: 0.6568, Accuracy: 52.93%
# Iteration 841/1000, Loss: 0.6567, Accuracy: 52.98%
# Iteration 842/1000, Loss: 0.6567, Accuracy: 53.03%
# Iteration 843/1000, Loss: 0.6566, Accuracy: 53.03%
# Iteration 844/1000, Loss: 0.6566, Accuracy: 53.03%
# Iteration 845/1000, Loss: 0.6566, Accuracy: 53.03%
# Iteration 846/1000, Loss: 0.6565, Accuracy: 53.03%
# Iteration 847/1000, Loss: 0.6565, Accuracy: 53.03%
# Iteration 848/1000, Loss: 0.6565, Accuracy: 53.03%
# Iteration 849/1000, Loss: 0.6564, Accuracy: 53.03%
# Iteration 850/1000, Loss: 0.6564, Accuracy: 53.03%
# Iteration 851/1000, Loss: 0.6563, Accuracy: 53.03%
# Iteration 852/1000, Loss: 0.6563, Accuracy: 53.03%
# Iteration 853/1000, Loss: 0.6563, Accuracy: 53.08%
# Iteration 854/1000, Loss: 0.6562, Accuracy: 53.08%
# Iteration 855/1000, Loss: 0.6562, Accuracy: 53.12%
# Iteration 856/1000, Loss: 0.6562, Accuracy: 53.12%
# Iteration 857/1000, Loss: 0.6561, Accuracy: 53.12%
# Iteration 858/1000, Loss: 0.6561, Accuracy: 53.17%
# Iteration 859/1000, Loss: 0.6560, Accuracy: 53.17%
# Iteration 860/1000, Loss: 0.6560, Accuracy: 53.22%
# Iteration 861/1000, Loss: 0.6560, Accuracy: 53.22%
# Iteration 862/1000, Loss: 0.6559, Accuracy: 53.22%
# Iteration 863/1000, Loss: 0.6559, Accuracy: 53.27%
# Iteration 864/1000, Loss: 0.6559, Accuracy: 53.27%
# Iteration 865/1000, Loss: 0.6558, Accuracy: 53.27%
# Iteration 866/1000, Loss: 0.6558, Accuracy: 53.32%
# Iteration 867/1000, Loss: 0.6557, Accuracy: 53.32%
# Iteration 868/1000, Loss: 0.6557, Accuracy: 53.32%
# Iteration 869/1000, Loss: 0.6557, Accuracy: 53.32%
# Iteration 870/1000, Loss: 0.6556, Accuracy: 53.32%
# Iteration 871/1000, Loss: 0.6556, Accuracy: 53.32%
# Iteration 872/1000, Loss: 0.6556, Accuracy: 53.42%
# Iteration 873/1000, Loss: 0.6555, Accuracy: 53.42%
# Iteration 874/1000, Loss: 0.6555, Accuracy: 53.52%
# Iteration 875/1000, Loss: 0.6554, Accuracy: 53.56%
# Iteration 876/1000, Loss: 0.6554, Accuracy: 53.56%
# Iteration 877/1000, Loss: 0.6554, Accuracy: 53.56%
# Iteration 878/1000, Loss: 0.6553, Accuracy: 53.61%
# Iteration 879/1000, Loss: 0.6553, Accuracy: 53.66%
# Iteration 880/1000, Loss: 0.6553, Accuracy: 53.71%
# Iteration 881/1000, Loss: 0.6552, Accuracy: 53.71%
# Iteration 882/1000, Loss: 0.6552, Accuracy: 53.71%
# Iteration 883/1000, Loss: 0.6551, Accuracy: 53.76%
# Iteration 884/1000, Loss: 0.6551, Accuracy: 53.76%
# Iteration 885/1000, Loss: 0.6551, Accuracy: 53.76%
# Iteration 886/1000, Loss: 0.6550, Accuracy: 53.76%
# Iteration 887/1000, Loss: 0.6550, Accuracy: 53.91%
# Iteration 888/1000, Loss: 0.6550, Accuracy: 53.91%
# Iteration 889/1000, Loss: 0.6549, Accuracy: 53.91%
# Iteration 890/1000, Loss: 0.6549, Accuracy: 53.91%
# Iteration 891/1000, Loss: 0.6548, Accuracy: 53.91%
# Iteration 892/1000, Loss: 0.6548, Accuracy: 53.91%
# Iteration 893/1000, Loss: 0.6548, Accuracy: 53.91%
# Iteration 894/1000, Loss: 0.6547, Accuracy: 53.96%
# Iteration 895/1000, Loss: 0.6547, Accuracy: 53.96%
# Iteration 896/1000, Loss: 0.6547, Accuracy: 54.00%
# Iteration 897/1000, Loss: 0.6546, Accuracy: 54.00%
# Iteration 898/1000, Loss: 0.6546, Accuracy: 54.00%
# Iteration 899/1000, Loss: 0.6545, Accuracy: 54.10%
# Iteration 900/1000, Loss: 0.6545, Accuracy: 54.10%
# Iteration 901/1000, Loss: 0.6545, Accuracy: 54.15%
# Iteration 902/1000, Loss: 0.6544, Accuracy: 54.15%
# Iteration 903/1000, Loss: 0.6544, Accuracy: 54.20%
# Iteration 904/1000, Loss: 0.6544, Accuracy: 54.25%
# Iteration 905/1000, Loss: 0.6543, Accuracy: 54.25%
# Iteration 906/1000, Loss: 0.6543, Accuracy: 54.30%
# Iteration 907/1000, Loss: 0.6542, Accuracy: 54.35%
# Iteration 908/1000, Loss: 0.6542, Accuracy: 54.35%
# Iteration 909/1000, Loss: 0.6542, Accuracy: 54.35%
# Iteration 910/1000, Loss: 0.6541, Accuracy: 54.35%
# Iteration 911/1000, Loss: 0.6541, Accuracy: 54.35%
# Iteration 912/1000, Loss: 0.6541, Accuracy: 54.35%
# Iteration 913/1000, Loss: 0.6540, Accuracy: 54.35%
# Iteration 914/1000, Loss: 0.6540, Accuracy: 54.35%
# Iteration 915/1000, Loss: 0.6539, Accuracy: 54.49%
# Iteration 916/1000, Loss: 0.6539, Accuracy: 54.54%
# Iteration 917/1000, Loss: 0.6539, Accuracy: 54.64%
# Iteration 918/1000, Loss: 0.6538, Accuracy: 54.64%
# Iteration 919/1000, Loss: 0.6538, Accuracy: 54.69%
# Iteration 920/1000, Loss: 0.6538, Accuracy: 54.69%
# Iteration 921/1000, Loss: 0.6537, Accuracy: 54.69%
# Iteration 922/1000, Loss: 0.6537, Accuracy: 54.69%
# Iteration 923/1000, Loss: 0.6536, Accuracy: 54.69%
# Iteration 924/1000, Loss: 0.6536, Accuracy: 54.69%
# Iteration 925/1000, Loss: 0.6536, Accuracy: 54.69%
# Iteration 926/1000, Loss: 0.6535, Accuracy: 54.69%
# Iteration 927/1000, Loss: 0.6535, Accuracy: 54.74%
# Iteration 928/1000, Loss: 0.6535, Accuracy: 54.74%
# Iteration 929/1000, Loss: 0.6534, Accuracy: 54.74%
# Iteration 930/1000, Loss: 0.6534, Accuracy: 54.74%
# Iteration 931/1000, Loss: 0.6533, Accuracy: 54.74%
# Iteration 932/1000, Loss: 0.6533, Accuracy: 54.74%
# Iteration 933/1000, Loss: 0.6533, Accuracy: 54.74%
# Iteration 934/1000, Loss: 0.6532, Accuracy: 54.74%
# Iteration 935/1000, Loss: 0.6532, Accuracy: 54.79%
# Iteration 936/1000, Loss: 0.6532, Accuracy: 54.83%
# Iteration 937/1000, Loss: 0.6531, Accuracy: 54.83%
# Iteration 938/1000, Loss: 0.6531, Accuracy: 54.83%
# Iteration 939/1000, Loss: 0.6530, Accuracy: 54.88%
# Iteration 940/1000, Loss: 0.6530, Accuracy: 54.93%
# Iteration 941/1000, Loss: 0.6530, Accuracy: 54.93%
# Iteration 942/1000, Loss: 0.6529, Accuracy: 54.93%
# Iteration 943/1000, Loss: 0.6529, Accuracy: 54.98%
# Iteration 944/1000, Loss: 0.6529, Accuracy: 54.98%
# Iteration 945/1000, Loss: 0.6528, Accuracy: 55.03%
# Iteration 946/1000, Loss: 0.6528, Accuracy: 55.03%
# Iteration 947/1000, Loss: 0.6527, Accuracy: 55.03%
# Iteration 948/1000, Loss: 0.6527, Accuracy: 55.03%
# Iteration 949/1000, Loss: 0.6527, Accuracy: 55.03%
# Iteration 950/1000, Loss: 0.6526, Accuracy: 55.03%
# Iteration 951/1000, Loss: 0.6526, Accuracy: 55.03%
# Iteration 952/1000, Loss: 0.6526, Accuracy: 55.08%
# Iteration 953/1000, Loss: 0.6525, Accuracy: 55.08%
# Iteration 954/1000, Loss: 0.6525, Accuracy: 55.08%
# Iteration 955/1000, Loss: 0.6525, Accuracy: 55.13%
# Iteration 956/1000, Loss: 0.6524, Accuracy: 55.18%
# Iteration 957/1000, Loss: 0.6524, Accuracy: 55.18%
# Iteration 958/1000, Loss: 0.6523, Accuracy: 55.18%
# Iteration 959/1000, Loss: 0.6523, Accuracy: 55.22%
# Iteration 960/1000, Loss: 0.6523, Accuracy: 55.27%
# Iteration 961/1000, Loss: 0.6522, Accuracy: 55.37%
# Iteration 962/1000, Loss: 0.6522, Accuracy: 55.37%
# Iteration 963/1000, Loss: 0.6522, Accuracy: 55.42%
# Iteration 964/1000, Loss: 0.6521, Accuracy: 55.42%
# Iteration 965/1000, Loss: 0.6521, Accuracy: 55.42%
# Iteration 966/1000, Loss: 0.6520, Accuracy: 55.47%
# Iteration 967/1000, Loss: 0.6520, Accuracy: 55.52%
# Iteration 968/1000, Loss: 0.6520, Accuracy: 55.57%
# Iteration 969/1000, Loss: 0.6519, Accuracy: 55.62%
# Iteration 970/1000, Loss: 0.6519, Accuracy: 55.66%
# Iteration 971/1000, Loss: 0.6519, Accuracy: 55.66%
# Iteration 972/1000, Loss: 0.6518, Accuracy: 55.66%
# Iteration 973/1000, Loss: 0.6518, Accuracy: 55.71%
# Iteration 974/1000, Loss: 0.6517, Accuracy: 55.71%
# Iteration 975/1000, Loss: 0.6517, Accuracy: 55.71%
# Iteration 976/1000, Loss: 0.6517, Accuracy: 55.76%
# Iteration 977/1000, Loss: 0.6516, Accuracy: 55.76%
# Iteration 978/1000, Loss: 0.6516, Accuracy: 55.81%
# Iteration 979/1000, Loss: 0.6516, Accuracy: 55.86%
# Iteration 980/1000, Loss: 0.6515, Accuracy: 55.86%
# Iteration 981/1000, Loss: 0.6515, Accuracy: 55.86%
# Iteration 982/1000, Loss: 0.6514, Accuracy: 55.91%
# Iteration 983/1000, Loss: 0.6514, Accuracy: 55.91%
# Iteration 984/1000, Loss: 0.6514, Accuracy: 55.96%
# Iteration 985/1000, Loss: 0.6513, Accuracy: 56.01%
# Iteration 986/1000, Loss: 0.6513, Accuracy: 56.05%
# Iteration 987/1000, Loss: 0.6513, Accuracy: 56.05%
# Iteration 988/1000, Loss: 0.6512, Accuracy: 56.05%
# Iteration 989/1000, Loss: 0.6512, Accuracy: 56.05%
# Iteration 990/1000, Loss: 0.6512, Accuracy: 56.05%
# Iteration 991/1000, Loss: 0.6511, Accuracy: 56.05%
# Iteration 992/1000, Loss: 0.6511, Accuracy: 56.10%
# Iteration 993/1000, Loss: 0.6510, Accuracy: 56.10%
# Iteration 994/1000, Loss: 0.6510, Accuracy: 56.20%
# Iteration 995/1000, Loss: 0.6510, Accuracy: 56.20%
# Iteration 996/1000, Loss: 0.6509, Accuracy: 56.20%
# Iteration 997/1000, Loss: 0.6509, Accuracy: 56.20%
# Iteration 998/1000, Loss: 0.6509, Accuracy: 56.20%
# Iteration 999/1000, Loss: 0.6508, Accuracy: 56.20%
# Iteration 1000/1000, Loss: 0.6508, Accuracy: 56.30%

# %% [markdown]
# <font color=orange>Reviewer's comments: Accuracy was too low. Try to bring it up **above 0.95**. -12</font>

# %%
# Visualize decision boundary after training
plt.scatter(features_train[:, 0], features_train[:, 1], s=5*np.ones(labels_train.size), c=labels_train, cmap='coolwarm')
xx, yy = np.meshgrid(np.linspace(0., 1., 300),
                     np.linspace(0., 1., 300))
zz = w[0, 0] * xx + w[0, 1] * yy + b - 0.5
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['blue', 'red'], alpha=0.25)
plt.title('Decision Boundary after Training')
# Out:
# Text(0.5, 1.0, 'Decision Boundary after Training')

# %% [markdown]
# ## 5. Evaluate Model with a New Dataset
# Let's generate a similar dataset using [make_blobs](https://scikit-learn.org/stable/modules/generated/sklearn.datasets.make_blobs.html#sklearn.datasets.make_blobs) as used in the beginning of this practice.
# Make predictions and evaluate model with this newly generated dataset.

# %%
# Accuracy on training data
X_raw, y_raw = make_blobs(n_samples=512, centers=np.array([[5, 5], [7, 8]]), cluster_std=1.0,)
features_test = X_raw / X_raw.max(axis=0)  # Scale features to [-1, 1]
labels_test = y_raw.reshape(-1, 1)  # Reshape labels to be a column vector

# Visualize test data
plt.scatter(
    features_test[:, 0], 
    features_test[:, 1], 
    s=5*np.ones(labels_test.size), 
    c=labels_test, 
    cmap='managua'  # color map
)
# Visualize decision boundary on test data
plt.contourf(xx, yy, zz, levels=[-np.inf, 0, np.inf], colors=['orange', 'cyan'], alpha=0.25)
plt.title('Decision Boundary on Test Data')
# Out:
# Text(0.5, 1.0, 'Decision Boundary on Test Data')

# %% [markdown]
# Besides accuracy, a handful of metrics are useful to evaluate how sensitive/precise/balance the model is.
# A confusion matrix is a handy tool to visualize these metrics.

# %%
# Confusion Matrix for Test Data
from sklearn.metrics import confusion_matrix, ConfusionMatrixDisplay

preds_test = forward(features_test, w, b)
cm_test = confusion_matrix(labels_test, (preds_test >= 0.5).astype(int))
disp_test = ConfusionMatrixDisplay(confusion_matrix=cm_test, display_labels=[0, 1])
disp_test.plot(cmap='PuRd')
plt.title('Confusion Matrix - Test Data')
# Out:
# Text(0.5, 1.0, 'Confusion Matrix - Test Data')

# %% [markdown]
# ### <font color=#582C83>(25%) Exercise 6: Classification Metrics</font>
# According to your confusion matrix on the **test dataset**. Please calculate the following metrics and write your answers below.
# > Let $0$ be negative, and $1$ be positive.
#
# - `Accuracy`= (TP + TN)/(TP + TN + FP + FN)
# -              = (256 + 34) / (256 + 34 + 222 + 0) = 56.6%
# - `Recall`= TP / (TP + FN)
# -              = 256 / (256 + 0) = 100%
# - `Precision`= TP/ (TP + FP)
# -              = 256/(256+222) = 53.6%
# - `F1 Score`= 2 * (Precision * Recall / Recision + Recall)
# -              = 69.8%
#
# <font color=#582C83>Assume the model is used by the quality control department in a factory to detect defective products (class 1).
# Please briefly state (2 sentences maximum) why or why not this model is good for this job.</font>
# > Please write down your answer below.
#   This model detects all defective products, Recall = 100%, but it has many false flags on normal items. For quality control, all defective items are counted but a lot of the good product will still get counted as a defective items, resulting in waste or extra time to re-inspect.

# %% [markdown]
# <font color=orange>Reviewer's comments: Your calculations were correct. Your analyses make sense. But, you did not conclude if the model fits the job or not. -5.</font>

# %% [markdown]
# # Congratulations! You have finished this assignment!
# ## <font color=orange>83/100</font>
